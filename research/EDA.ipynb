# %% [markdown]
# # EDA On Our Dataset

# %% [markdown]
# ## Tasks:
# - High Level Exploring of data
# - Univariate Analysis
# - Bivariate Analysis

# %% [markdown]
# ### Importing Necessary Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading our dataset

# %%
df = pd.read_csv('data/raw/health_fitness_dataset.csv')

# %% [markdown]
# ### Loading top 5 rows

# %%
df.head()
# Out:
#    participant_id        date  age gender  height_cm  weight_kg  \
# 0               1  2024-01-01   56      F      165.3       53.7
# 1               1  2024-01-04   56      F      165.3       53.9
# 2               1  2024-01-05   56      F      165.3       54.2
# 3               1  2024-01-07   56      F      165.3       54.4
# 4               1  2024-01-09   56      F      165.3       54.7
#
#      activity_type  duration_minutes intensity  calories_burned  ...  \
# 0          Dancing                41       Low              3.3  ...
# 1         Swimming                28       Low              2.9  ...
# 2         Swimming                21    Medium              2.6  ...
# 3  Weight Training                99    Medium             10.7  ...
# 4         Swimming               100    Medium             12.7  ...
#
#    stress_level  daily_steps  hydration_level   bmi  resting_heart_rate  \
# 0             3         7128              1.5  19.6                69.5
# ...

# %% [markdown]
# ### Checking out the shape of our data

# %%
df.shape
# Out:
# (687701, 22)

# %% [markdown]
# - We have 687701 rows and 22 columns

# %% [markdown]
# ### Checking out the data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687701 entries, 0 to 687700
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   participant_id            687701 non-null  int64
#  1   date                      687701 non-null  object
#  2   age                       687701 non-null  int64
#  3   gender                    687701 non-null  object
#  4   height_cm                 687701 non-null  float64
#  5   weight_kg                 687701 non-null  float64
#  6   activity_type             687701 non-null  object
#  7   duration_minutes          687701 non-null  int64
#  8   intensity                 687701 non-null  object
#  9   calories_burned           687701 non-null  float64
#  10  avg_heart_rate            687701 non-null  int64
#  11  hours_sleep               687701 non-null  float64
#  12  stress_level              687701 non-null  int64
# ...

# %% [markdown]
# ### Checking out the Statistics of our data

# %%
df.describe()
# Out:
#        participant_id            age      height_cm      weight_kg  \
# count   687701.000000  687701.000000  687701.000000  687701.000000
# mean      1499.781828      41.658602     168.587699      94.921981
# std        865.997215      13.581770       9.140811      22.461801
# min          1.000000      18.000000     145.000000      45.300000
# 25%        749.000000      30.000000     161.700000      78.200000
# 50%       1499.000000      42.000000     168.200000      94.600000
# 75%       2249.000000      53.000000     175.300000     110.500000
# max       3000.000000      64.000000     198.500000     188.400000
#
#        duration_minutes  calories_burned  avg_heart_rate    hours_sleep  \
# count     687701.000000    687701.000000   687701.000000  687701.000000
# mean          70.011671        15.381302      131.454165       7.048799
# std           29.147251         9.985552       17.814744       0.972068
# min           20.000000         0.800000       82.000000       4.000000
# ...

# %% [markdown]
# ### Checking and handling Missing Values

# %%
df.isnull().sum()
# Out:
# participant_id                   0
# date                             0
# age                              0
# gender                           0
# height_cm                        0
# weight_kg                        0
# activity_type                    0
# duration_minutes                 0
# intensity                        0
# calories_burned                  0
# avg_heart_rate                   0
# hours_sleep                      0
# stress_level                     0
# daily_steps                      0
# hydration_level                  0
# bmi                              0
# resting_heart_rate               0
# blood_pressure_systolic          0
# blood_pressure_diastolic         0
# health_condition            490275
# smoking_status                   0
# fitness_level                    0
# dtype: int64

# %%
df.drop('health_condition', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# participant_id              0
# date                        0
# age                         0
# gender                      0
# height_cm                   0
# weight_kg                   0
# activity_type               0
# duration_minutes            0
# intensity                   0
# calories_burned             0
# avg_heart_rate              0
# hours_sleep                 0
# stress_level                0
# daily_steps                 0
# hydration_level             0
# bmi                         0
# resting_heart_rate          0
# blood_pressure_systolic     0
# blood_pressure_diastolic    0
# smoking_status              0
# fitness_level               0
# dtype: int64

# %% [markdown]
# - Dropped the highest missing value column

# %% [markdown]
# ### Checking out the columns of our data

# %%
df.columns
# Out:
# Index(['participant_id', 'date', 'age', 'gender', 'height_cm', 'weight_kg',
#        'activity_type', 'duration_minutes', 'intensity', 'calories_burned',
#        'avg_heart_rate', 'hours_sleep', 'stress_level', 'daily_steps',
#        'hydration_level', 'bmi', 'resting_heart_rate',
#        'blood_pressure_systolic', 'blood_pressure_diastolic', 'smoking_status',
#        'fitness_level'],
#       dtype='object')

# %% [markdown]
# ### Dropping Unnecessary Columns

# %%
df.drop(['participant_id','date'], axis=1, inplace=True)

# %% [markdown]
# - Dropped participant_id & date columns

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Plotting the Distribution of Age

# %%
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
sns.histplot(data=df, x='age', kde=True)

plt.subplot(1,2,2)
sns.histplot(data=df, x='age', kde=True, hue='gender')
plt.title('age - gender')
# Out:
# Text(0.5, 1.0, 'age - gender')

# %%
sns.violinplot(data=df, x='age')
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ### Insights
# - Age is perfectly distributed evenly

# %% [markdown]
# ### Visulaizing the Distribution of height_cm

# %%
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
sns.histplot(data=df, x='height_cm', kde=True)
plt.title('height_cm')


plt.subplot(1,2,2)
sns.histplot(data=df, x='height_cm', kde=True, hue='gender')
plt.title('height_cm - gender')
# Out:
# Text(0.5, 1.0, 'height_cm - gender')

# %% [markdown]
# ### Insights
# - Males heights are bigger than Females

# %% [markdown]
# ### Visualizing the distribution of weight_kg

# %%
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
sns.histplot(data=df, x='weight_kg', kde=True)
plt.title('weight_kg')


plt.subplot(1,2,2)
sns.histplot(data=df, x='weight_kg', kde=True, hue='gender')
plt.title('weight_kg - gender')
# Out:
# Text(0.5, 1.0, 'weight_kg - gender')

# %% [markdown]
# ### Insights
# - Males weights are higher than Females

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1,2,1)
sns.countplot(data=df, x='gender', hue='gender')

plt.subplot(1,2,2)
df.gender.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Insights
# - Males and Females counts are almost same

# %% [markdown]
# ### Visualizing the counts of gender based on columns

# %%
plt.figure(figsize=(16,7))
plt.subplot(1,3,1)
sns.countplot(data=df, x='gender', hue='activity_type')
plt.title('gender - activity_type')

plt.subplot(1,3,2)
sns.countplot(data=df, x='gender', hue='intensity')
plt.title('gender - intensity')

plt.subplot(1,3,3)
sns.countplot(data=df, x='gender', hue='smoking_status')
plt.title('gender - smoking_status')
# Out:
# Text(0.5, 1.0, 'gender - smoking_status')

# %% [markdown]
# ### Insights
# - Females are active in all kind of activites but like to do more cycling and yoga
# - Males are also active in all sports but more likely to be present in weight training
# - Both genders prefer activites of Medium intensity
# - Both gender are more likely to not smoke

# %% [markdown]
# ### Visualizing distribution of fitness_level

# %%
sns.violinplot(data=df, x='fitness_level')
# Out:
# <Axes: xlabel='fitness_level'>

# %% [markdown]
# - Evenly distributed

# %% [markdown]
# ### Visualizing the distribution of calories_burned based on gender

# %%
sns.histplot(data=df, x='calories_burned', kde=True, hue='gender')
# Out:
# <Axes: xlabel='calories_burned', ylabel='Count'>

# %% [markdown]
# ### Insights
# - Both Males and Females burn almost same calories on average

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ### Visualizing the pair plot

# %% [markdown]
# ### Visualizing correlations

# %%
plt.figure(figsize=(17,9))
sns.heatmap(df[df.select_dtypes('number').columns].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Visualizing the relation between duration_mintues and calories_burned

# %%
sns.lineplot(data=df, x='duration_minutes', y='calories_burned')
# Out:
# <Axes: xlabel='duration_minutes', ylabel='calories_burned'>

# %% [markdown]
# ### Insights
# - The more you exercise the more calories you will burn

# %% [markdown]
# ### Visualizing the relation between hours_sleep and stress_level

# %%
sns.lineplot(data=df, x='hours_sleep', y='stress_level')
# Out:
# <Axes: xlabel='hours_sleep', ylabel='stress_level'>

# %% [markdown]
# ### Insights
# - stress will occur if we sleep less or more

# %% [markdown]
# ### Visualzing the relation between calories_burned and fitness_level

# %%
sns.scatterplot(data=df, x='calories_burned', y='fitness_level')
# Out:
# <Axes: xlabel='calories_burned', ylabel='fitness_level'>

# %% [markdown]
# ### Insights
# - The result is evenly spreaded
